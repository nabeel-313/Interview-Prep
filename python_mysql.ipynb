# %%
print("hello")
# Out:
# hello

# %%
# importing required libraries
import mysql.connector

dataBase = mysql.connector.connect(
host ="localhost",
user ="root",
passwd ="nabeel"
)

print(dataBase)

# Disconnecting from the server
# dataBase.close()

# %%
# preparing a cursor object
cursorObject = dataBase.cursor()
 
# creating database
cursorObject.execute("use test")

# %%
cursorObject.execute("select * from advertise;")

# %%
myresult = cursorObject.fetchall()
   
for x in myresult:
    print(x)
 
# disconnecting from server
#dataBase.close()
# Out:
# (1, 230.10001, 37.8, 69.2, 22.1)
# (2, 44.5, 39.3, 45.1, 10.4)
# (3, 17.2, 45.9, 69.3, 9.3)
# (4, 151.5, 41.3, 58.5, 18.5)
# (5, 180.8, 10.8, 58.4, 12.9)
# (6, 8.7, 48.9, 75.0, 7.2)
# (7, 57.5, 32.8, 23.5, 11.8)
# (8, 120.2, 19.6, 11.6, 13.2)
# (9, 8.6, 2.1, 1.0, 4.8)
# (10, 199.8, 2.6, 21.2, 10.6)
# (11, 66.1, 5.8, 24.2, 8.6)
# (12, 214.7, 24.0, 4.0, 17.4)
# (13, 23.8, 35.1, 65.9, 9.2)
# (14, 97.5, 7.6, 7.2, 9.7)
# (15, 204.10001, 32.9, 46.0, 19.0)
# (16, 195.39999, 47.7, 52.9, 22.4)
# (17, 67.8, 36.6, 114.0, 12.5)
# (18, 281.39999, 39.6, 55.8, 24.4)
# (19, 69.2, 20.5, 18.3, 11.3)
# (20, 147.3, 23.9, 19.1, 14.6)
# (21, 218.39999, 27.7, 53.4, 18.0)
# (22, 237.39999, 5.1, 23.5, 12.5)
# (23, 13.2, 15.9, 49.6, 5.6)
# (24, 228.3, 16.9, 26.2, 15.5)
# (25, 62.3, 12.6, 18.3, 9.7)
# (26, 262.89999, 3.5, 19.5, 12.0)
# (27, 142.89999, 29.3, 12.6, 15.0)
# (28, 240.10001, 16.7, 22.9, 15.9)
# (29, 248.8, 27.1, 22.9, 18.9)
# (30, 70.6, 16.0, 40.8, 10.5)
# (31, 292.89999, 28.3, 43.2, 21.4)
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
col_dtype ={}
for col in df:
    col_dtype[col] = df[col].dtype
col_dtype
# Out:
# {'PassengerId': dtype('int64'),
#  'Survived': dtype('int64'),
#  'Pclass': dtype('int64'),
#  'Name': dtype('O'),
#  'Sex': dtype('O'),
#  'Age': dtype('float64'),
#  'SibSp': dtype('int64'),
#  'Parch': dtype('int64'),
#  'Ticket': dtype('O'),
#  'Fare': dtype('float64'),
#  'Cabin': dtype('O'),
#  'Embarked': dtype('O')}

# %%
sql_query_table = ''' 
CREATE TABLE TitanicData (
    PassengerId int,
    Survived int,
    Pclass int,
    Name varchar(255),
    Sex varchar(255),
    Age float,
    SibSp int,
    Parch int,
    Ticket varchar(255),
    Fare float,
    Cabinet varchar(255),
    Embarked varchar(255)
)
'''

# %%
cursorObject.execute(''' 
                     CREATE TABLE TitanicData (
    PassengerId int,
    Survived int,
    Pclass int,
    Name varchar(255),
    Sex varchar(255),
    Age float,
    SibSp int,
    Parch int,
    Ticket varchar(255),
    Fare float,
    Cabinet varchar(255),
    Embarked varchar(255)
)
                     
                     ''')
dataBase.commit()

# %%
# for row in df.itertuples():
#     cursorObject.execute('''
#                 INSERT INTO TitanicData (PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked )
#                 VALUES (?,?,?,?,?,?,?,?,?,?,?,?)
#                 ''',
#                 row.PassengerId, 
#                 row.Survived,
#                 row.Pclass,
#                 row.Name,
#                 row.Sex,
#                 row.Age,
#                 row.SibSp,
#                 row.Parch,
#                 row.Ticket,
#                 row.Fare,
#                 row.Cabin,
#                 row.Embarked
                
#                 )
# dataBase.commit()

# %%
import csv
with open('titanic.csv', mode='r') as csv_file:
    #read csv using reader class
    csv_reader = csv.reader(csv_file)
    #skip header
    header = next(csv_reader)
    #Read csv row wise and insert into table
    for row in csv_reader:
        sql = "INSERT INTO users () VALUES (%s,%s,%s)"
        cursor.execute(sql, tuple(row))
        print("Record inserted")
 
conn.commit()
cursor.close()
