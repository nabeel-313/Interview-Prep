# %%
print(34)
# Out:
# 34

# %%
# nth fabo series
def foo(n):
    if n <= 1:
        return n
    return foo(n-1) + foo(n-2)
foo(10)

# def fabo(n):
#     a = 0 ; b = 1
#     for i in range(1,n):
#         c = a + b
#         a = b
#         b = c
#     return b
# fabo(10)
# Out:
# 55

# %%
def fact(n):
    if n <= 1:
        return n
    return n * fact(n-1)
fact(5)
# Out:
# 120
