# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ### Add the digit of given no until the result is single digit
# #### E.g.= no=38 -->> 3+8 = 11  -->> 1+1 = 2 ans is 3

# %%
def adddigit(num):
    digital_root = 0
    while num > 0:
        digital_root += num % 10
        num = num//10
        
        if num == 0 and digital_root > 9 :
            num = digital_root
            digital_root = 0
    return digital_root
adddigit(38)
# Out:
# 2

# %% [markdown]
# ### Given an integer write the no way we can write in sum of consecutive digit
# n = 5
# ans = 2 -->>  5, 2+3
#
# n = 15
# ans 4, -->> 15, 7+8, 4+5+6, 1+2+3+4+5
